# %%
import pandas as pd
import geopandas as gpd
import plotly.graph_objects as go
import os

# read shapefile perc_groen => groenkaart rivm percentage green
df_groen = gpd.read_file('../data/shape/breda_buurten_4326.shp')
df_groen.index = df_groen.BU_NAAM

# %%
# load evi data
import pandas as pd
df = pd.read_csv('../data/satdata/evi.csv', index_col=[0], parse_dates=[0]).dropna()
df = df.unstack().reset_index()
df.columns = ['buurt', 'datum', 'evi']
df_evi = df.groupby('buurt').mean()
df_evi.loc['Chassee'] = df_evi.loc['Chass̩']
df_evi
# Out:
#                                   evi
# buurt
# Bavel                     3060.530772
# Belcrum                   1543.054919
# Biesdonk                  2220.788460
# Blauwe Kei                2215.151373
# Boeimeer                  2340.471506
# Brabantpark               2279.530398
# Buitengebied Bavel        4009.694424
# Buitengebied Prinsenbeek  4199.554456
# Buitengebied Teteringen   3759.263934
# Buitengebied Ulvenhout    3954.206180
# Chass̩                   1568.224541
# City                      1305.761679
# Doornbos-Linie            2238.853477
# Effen-Rith                3912.605742
# Emer                      1934.200582
# Fellenoord                1623.873534
# Gageldonk                 2622.108504
# Geeren-noord              2743.308748
# Geeren-zuid               2365.034747
# Ginneken                  2855.682163
# Haagpoort                 1690.636581
# Hagebeemd                 3954.552282
# Hazeldonk                 3165.896847
# Heilaar                   2319.471418
# Heksenwiel                2743.754644
# Heusdenhout               2774.744752
# Heuvel                    2245.423750
# Hoogeind                  3088.988614
# Kesteren                  2424.368450
# Kievitsloop               2744.118220
# Kroeten                   2437.881367
# Krogten                   2604.103704
# Liesbos                   3556.887449
# Mastbos                   3672.065550
# Moleneind-oost            2163.302052
# Muizenberg                2746.656091
# Nieuw Wolfslaar           3241.024925
# Overakker                 3286.451905
# Overkroeten               2413.220735
# Princenhage               2611.365500
# Prinsenbeek               2685.551461
# Ruitersbos                3289.878551
# Schorsmolen               1246.819235
# Sportpark                 2267.659199
# Station                   1512.286867
# Steenakker                2338.779694
# Teteringen                3139.322679
# Tuinzigt                  1695.369506
# Ulvenhout                 3271.212112
# Valkenberg                1672.040045
# Vuchtpolder               4789.793277
# Waterdonken               2926.269140
# Westerpark                2292.134824
# Wisselaar                 2701.680421
# Ypelaar                   2616.648440
# Zandberg                  1911.930626
# Chassee                   1568.224541

# %%
df_groen_evi = df_evi.join(df_groen.perc_groen).dropna()
df_groen_evi
# Out:
#                                   evi  perc_groen
# buurt
# Bavel                     3060.530772   55.925788
# Belcrum                   1543.054919   25.283203
# Biesdonk                  2220.788460   43.226776
# Blauwe Kei                2215.151373   42.065574
# Boeimeer                  2340.471506   49.370830
# Brabantpark               2279.530398   46.272917
# Buitengebied Bavel        4009.694424   79.321258
# Buitengebied Prinsenbeek  4199.554456   83.411251
# Buitengebied Teteringen   3759.263934   87.063502
# Buitengebied Ulvenhout    3954.206180   83.747044
# City                      1305.761679   35.143023
# Doornbos-Linie            2238.853477   45.877331
# Effen-Rith                3912.605742   79.861742
# Emer                      1934.200582   50.722509
# Fellenoord                1623.873534   40.809302
# Gageldonk                 2622.108504   46.094593
# Geeren-noord              2743.308748   51.546812
# Geeren-zuid               2365.034747   47.218936
# Ginneken                  2855.682163   58.233344
# Haagpoort                 1690.636581   31.383523
# Hagebeemd                 3954.552282   84.246788
# Hazeldonk                 3165.896847   67.574252
# Heilaar                   2319.471418   53.466614
# Heksenwiel                2743.754644   47.197350
# Heusdenhout               2774.744752   56.023397
# Heuvel                    2245.423750   42.486676
# Hoogeind                  3088.988614   62.859483
# Kesteren                  2424.368450   44.325759
# Kievitsloop               2744.118220   46.627773
# Kroeten                   2437.881367   38.088432
# Krogten                   2604.103704   66.439295
# Liesbos                   3556.887449   77.211733
# Mastbos                   3672.065550   88.218311
# Moleneind-oost            2163.302052   45.183346
# Muizenberg                2746.656091   50.839890
# Nieuw Wolfslaar           3241.024925   58.802323
# Overakker                 3286.451905   71.867007
# Overkroeten               2413.220735   37.678661
# Princenhage               2611.365500   50.457265
# Prinsenbeek               2685.551461   50.053589
# Ruitersbos                3289.878551   71.611449
# Schorsmolen               1246.819235   31.882038
# Sportpark                 2267.659199   46.310246
# Station                   1512.286867   36.456099
# Steenakker                2338.779694   49.978780
# Teteringen                3139.322679   57.668575
# Tuinzigt                  1695.369506   33.898762
# Ulvenhout                 3271.212112   62.721829
# Valkenberg                1672.040045   50.181784
# Vuchtpolder               4789.793277   87.776908
# Waterdonken               2926.269140   44.504842
# Westerpark                2292.134824   41.964853
# Wisselaar                 2701.680421   45.698376
# Ypelaar                   2616.648440   49.926658
# Zandberg                  1911.930626   41.841221
# Chassee                   1568.224541   39.587123

# %%
import seaborn as sns
sns.jointplot(x='evi', y='perc_groen', data=df_groen_evi, kind='reg')

# %%
import numpy as np
# fit simple ax + b function on data
coefs = np.polyfit(df_groen_evi.perc_groen.values, df_groen_evi.evi.values, deg=1)
xnew = [10,25,50,75,90]
ffit = np.poly1d(coefs)
ffit(xnew) # calculate evi for percentages xnew
# Out:
# array([ 728.80795662, 1389.99689415, 2491.97845669, 3593.96001923,
#        4255.14895676])

# %%
xnew = 50
ffit(xnew) * -0.0012 # temp diff
ffit(xnew) * 0.67 # obs diff
# Out:
# 1669.6255659815429
